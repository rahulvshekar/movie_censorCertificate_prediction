# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from apyori import apriori

# %%
data1=pd.read_csv("C:\\Users\\devar\\Documents\\data_mining_project\\movies.csv")

# %%
data1.head(10)
# Out:
#      budget                                  company country  \
# 0   8000000            Columbia Pictures Corporation     USA
# 1   6000000                       Paramount Pictures     USA
# 2  15000000                       Paramount Pictures     USA
# 3  18500000   Twentieth Century Fox Film Corporation     USA
# 4   9000000                     Walt Disney Pictures     USA
# 5   6000000                                  Hemdale      UK
# 6  25000000                   Henson Associates (HA)      UK
# 7   6000000  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000                       Paramount Pictures     USA
# 9  15000000                     SLM Production Group     USA
#
#            director      genre      gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414               Stand by Me      R
# 1       John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# ...

# %%
data1.tail()
# Out:
#        budget                    company country         director      genre  \
# 6815        0   Fox Searchlight Pictures      UK  Mandie Fletcher     Comedy
# 6816        0   Siempre Viva Productions     USA   Paul Duddridge      Drama
# 6817  3500000     Warner Bros. Animation     USA          Sam Liu  Animation
# 6818        0        Borderline Presents     USA    Nicolas Pesce      Drama
# 6819        0  Les Productions du Trésor  France    Nicole Garcia      Drama
#
#         gross                            name rating    released  runtime  \
# 6815  4750497  Absolutely Fabulous: The Movie      R  22-07-2016      NaN
# 6816    28368           Mothers and Daughters  PG-13  06-05-2016     90.0
# 6817  3775000        Batman: The Killing Joke      R  25-07-2016     76.0
# 6818    25981           The Eyes of My Mother      R  02-12-2016     76.0
# 6819    37757       From the Land of the Moon      R  28-07-2017    120.0
#
# ...

# %%
data1.shape
# Out:
# (6820, 15)

# %%
data1.describe()
# Out:
#              budget         gross      runtime        score         votes  \
# count  6.820000e+03  6.820000e+03  6768.000000  6820.000000  6.819000e+03
# mean   2.458113e+07  3.349783e+07   106.560727     6.374897  7.122826e+04
# std    3.702254e+07  5.819760e+07    18.036689     1.003142  1.305252e+05
# min    0.000000e+00  7.000000e+01    50.000000     1.500000  2.700000e+01
# 25%    0.000000e+00  1.515839e+06    95.000000     5.800000  7.664500e+03
# 50%    1.100000e+07  1.213568e+07   102.000000     6.400000  2.589900e+04
# 75%    3.200000e+07  4.006534e+07   115.000000     7.100000  7.582250e+04
# max    3.000000e+08  9.366622e+08   366.000000     9.300000  1.861666e+06
#
#               year
# count  6815.000000
# mean   2000.992957
# std       8.940347
# min    1986.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2009.000000
# max    2016.000000

# %%
data1.boxplot()

# %%
data1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8ACF82D08>,
# ...
#       dtype=object)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6820 entries, 0 to 6819
# Data columns (total 15 columns):
# budget      6820 non-null int64
# company     6820 non-null object
# country     6818 non-null object
# director    6820 non-null object
# genre       6820 non-null object
# gross       6820 non-null int64
# name        6820 non-null object
# rating      6818 non-null object
# released    6820 non-null object
# runtime     6768 non-null float64
# score       6820 non-null float64
# star        6820 non-null object
# votes       6819 non-null float64
# writer      6820 non-null object
# year        6815 non-null float64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 799.3+ KB

# %%
data1.isnull().sum()
# Out:
# budget       0
# company      0
# country      2
# director     0
# genre        0
# gross        0
# name         0
# rating       2
# released     0
# runtime     52
# score        0
# star         0
# votes        1
# writer       0
# year         5
# dtype: int64

# %%
# removing data which is not much used for analysis
data1[data1.votes>1000000]
# Out:
#          budget                    company      country           director  \
# 1760   25000000  Castle Rock Entertainment          USA     Frank Darabont
# 1761    8000000                    Miramax          USA  Quentin Tarantino
# 1762   55000000         Paramount Pictures          USA    Robert Zemeckis
# 1980   33000000       Cecchi Gori Pictures          USA      David Fincher
# 2860   63000000          Fox 2000 Pictures          USA      David Fincher
# 2862   63000000               Warner Bros.          USA     Lana Wachowski
# 3081  103000000                 DreamWorks          USA       Ridley Scott
# 3301   93000000            New Line Cinema  New Zealand      Peter Jackson
# 3530   94000000            New Line Cinema          USA      Peter Jackson
# 3743   94000000            New Line Cinema          USA      Peter Jackson
# 4183  150000000               Warner Bros.          USA  Christopher Nolan
# ...

# %%
data1.shape
# Out:
# (6820, 15)

# %%
data1.drop([1760],inplace=True)
data1.drop([1761],inplace=True)
data1.drop([1762],inplace=True)
data1.drop([1980],inplace=True)
data1.drop([2860],inplace=True)
data1.drop([2862],inplace=True)
data1.drop([3081],inplace=True)
data1.drop([3301],inplace=True)
data1.drop([3530],inplace=True)
data1.drop([3743],inplace=True)
data1.drop([4183],inplace=True)
data1.drop([4840],inplace=True)
data1.drop([5280],inplace=True)
data1.drop([5720],inplace=True)
data1.drop([5721],inplace=True)
data1.drop([5723],inplace=True)
data1.drop([6161],inplace=True)

# %%
data1[data1.votes>1000000]
# Out:
# Empty DataFrame
# Columns: [budget, company, country, director, genre, gross, name, rating, released, runtime, score, star, votes, writer, year]
# Index: []

# %%
data1.shape
# Out:
# (6803, 15)

# %%
data1[data1.runtime>300]
# Out:
#       budget    company country               director  genre    gross  \
# 395        0      Sands      UK       Christine Edzard  Drama  1025228
# 3890       0  BiBi Film   Italy  Marco Tullio Giordana  Drama   254224
#
#                    name rating    released  runtime  score             star  \
# 395       Little Dorrit      G  21-10-1988    357.0    7.5     Derek Jacobi
# 3890  The Best of Youth      R  20-06-2003    366.0    8.5  Luigi Lo Cascio
#
#         votes            writer    year
# 395     886.0   Charles Dickens  1987.0
# 3890  17585.0  Sandro Petraglia  2003.0

# %%
data1.drop([395],inplace=True)
data1.drop([3890],inplace=True)

# %%
data1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8AE7C47C8>,
# ...
#       dtype=object)

# %%
data1.shape
# Out:
# (6801, 15)

# %%
threshold=len(data1)*0.1

# %%
data1.dropna(thresh=threshold,axis=1,inplace=True)

# %%
print(data1.isnull().sum())
# Out:
# budget       0
# company      0
# country      2
# director     0
# genre        0
# gross        0
# name         0
# rating       2
# released     0
# runtime     52
# score        0
# star         0
# votes        1
# writer       0
# year         5
# dtype: int64

# %%
def inpute_median(series):
    return series.fillna(series.median())

# %%
data1.runtime=data1['runtime'].transform(inpute_median)
data1.votes=data1['votes'].transform(inpute_median)
data1.year=data1['year'].transform(inpute_median)

# %%
data1.isnull().sum()
# Out:
# budget      0
# company     0
# country     2
# director    0
# genre       0
# gross       0
# name        0
# rating      2
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
print(data1['country'].mode())
print(data1['rating'].mode())
# Out:
# 0    USA
# dtype: object
# 0    R
# dtype: object

# %%
data1['country'].fillna(str(data1['country'].mode().values[0]),inplace=True)
data1['rating'].fillna(str(data1['rating'].mode().values[0]),inplace=True)

# %%
data1.isnull().sum()
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
data1.describe()
# Out:
#              budget         gross      runtime        score          votes  \
# count  6.801000e+03  6.801000e+03  6801.000000  6801.000000    6801.000000
# mean   2.437617e+07  3.293611e+07   106.328187     6.368652   68081.612778
# std    3.667462e+07  5.655274e+07    17.259428     0.997352  113686.877278
# min    0.000000e+00  7.000000e+01    50.000000     1.500000      27.000000
# 25%    0.000000e+00  1.512815e+06    95.000000     5.800000    7657.000000
# 50%    1.100000e+07  1.206589e+07   102.000000     6.400000   25828.500000
# 75%    3.200000e+07  3.967316e+07   114.000000     7.100000   75099.000000
# max    3.000000e+08  9.366622e+08   280.000000     8.900000  990212.000000
#
#               year
# count  6801.000000
# mean   2000.989266
# std       8.940705
# min    1986.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2009.000000
# max    2016.000000

# %%
#visualtization

# %%
grp=data1.groupby('genre')
x = grp['budget'].agg(np.mean)
y = grp['gross'].agg(np.mean)
z = grp['runtime'].agg(np.mean)
a = grp['score'].agg(np.mean)
b = grp['votes'].agg(np.mean)
c = grp['year'].agg(np.mean)

# %%
print(x)
print(y)
print(z)
print(a)
print(b)
print(c)
# Out:
# genre
# Action       4.829406e+07
# Adventure    3.653668e+07
# Animation    6.432671e+07
# Biography    1.695594e+07
# Comedy       1.490287e+07
# Crime        1.624268e+07
# Drama        1.318800e+07
# Family       8.537857e+06
# Fantasy      1.576381e+07
# Horror       1.184693e+07
# Musical      2.500000e+06
# Mystery      2.684342e+07
# Romance      5.480000e+06
# Sci-Fi       1.688462e+07
# Thriller     5.888889e+06
# War          0.000000e+00
# Western      6.000000e+06
# Name: budget, dtype: float64
# genre
# Action       5.462815e+07
# Adventure    5.069879e+07
# Animation    9.148810e+07
# Biography    2.400425e+07
# Comedy       2.559556e+07
# Crime        1.923206e+07
# Drama        1.736355e+07
# Family       8.436443e+06
# Fantasy      2.014541e+07
# Horror       2.569620e+07
# Musical      2.023748e+06
# Mystery      3.631451e+07
# Romance      9.717614e+06
# Sci-Fi       2.367705e+07
# Thriller     5.533345e+06
# War          7.548875e+05
# Western      9.259547e+06
# ...

# %%
plt.figure(figsize=(12,5))
plt.plot(x, 'ro')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.plot(x,'ro', color='r')
plt.xticks(rotation=90)
plt.title('genre wise budget')
plt.xlabel('Genre-->')
plt.ylabel('Budget-->')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--', color='b')
plt.xticks(rotation=90)
plt.title('Genre wise Gross')
plt.xlabel('Genre-->')
plt.ylabel('Gross-->')
plt.show()

# %%
#apriori function
data1.shape
# Out:
# (6801, 15)

# %%
df=pd.DataFrame(data1)

# %%
df.to_csv("temp.csv")

# %%
temp_data=pd.read_csv("temp.csv",header=None)

# %%
temp_data.shape
# Out:
# (6802, 16)

# %%
final_data=temp_data.drop([0],axis=1)

# %%
final_data
# Out:
#             1                                       2        3   \
# 0       budget                                 company  country
# 1      8000000           Columbia Pictures Corporation      USA
# 2      6000000                      Paramount Pictures      USA
# 3     15000000                      Paramount Pictures      USA
# 4     18500000  Twentieth Century Fox Film Corporation      USA
# ...        ...                                     ...      ...
# 6797         0                Fox Searchlight Pictures       UK
# 6798         0                Siempre Viva Productions      USA
# 6799   3500000                  Warner Bros. Animation      USA
# 6800         0                     Borderline Presents      USA
# 6801         0               Les Productions du Trésor   France
#
#                    4          5          6                               7   \
# 0            director      genre      gross                            name
# ...

# %%
final_data.shape
# Out:
# (6802, 15)

# %%
records = []
for i in range(0, 6802):
    records.append([str(final_data.values[i,j]) for j in range(0, 15)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_result = list(association_rules)

# %%
print(len(association_result))
# Out:
# 13

# %%
print(association_result[0])
# Out:
# RelationRecord(items=frozenset({'G', 'Animation'}), support=0.013084386945016171, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Animation'}), items_add=frozenset({'G'}), confidence=0.32129963898916963, lift=14.969042084961178), OrderedStatistic(items_base=frozenset({'G'}), items_add=frozenset({'Animation'}), confidence=0.6095890410958904, lift=14.96904208496118)])

# %%
for item in association_result:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: G -> Animation
# Support: 0.013084386945016171
# Confidence: 0.32129963898916963
# Lift: 14.969042084961178
# ...
# Rule: PG -> Animation
# Support: 0.0223463687150838
# Confidence: 0.5487364620938628
# Lift: 3.928953068592058
# ...
# Rule: NOT RATED -> France
# Support: 0.005145545427815349
# Confidence: 0.20114942528735633
# Lift: 4.8346939604402746
# ...
# Rule: PG -> Walt Disney Pictures
# Support: 0.009556012937371362
# Confidence: 0.6372549019607844
# Lift: 4.562745098039216
# ...
# Rule: 0 -> UK
# Support: 0.00558659217877095
# Confidence: 0.31666666666666665
# Lift: 3.09477969348659
# ...
# Rule: 0 -> NOT RATED
# Support: 0.008967950602763893
# Confidence: 0.3505747126436782
# Lift: 3.674282273347148
# ...
# Rule: 0 -> NOT RATED
# Support: 0.00455748309320788
# Confidence: 0.22794117647058823
# Lift: 5.4786426938266475
# ...
# Rule: PG -> Adventure
# Support: 0.01720082328726845
# Confidence: 0.43656716417910446
# Lift: 3.1258208955223883
# ...
# Rule: G -> Animation
# Support: 0.009408997353719493
# ...
